# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\ayush ranjan\anaconda3\lib\site-packages (1.51.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (6.2.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<26,>=20 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (6.33.0)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.10.2)
# Requirement already satisfied: colorama in c:\users\ayush ranjan\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)

# %%
pip install import-ipynb
# Out:
# Collecting import-ipynb
#   Obtaining dependency information for import-ipynb from https://files.pythonhosted.org/packages/ec/62/e0b830773060d2a390aa923dcc8afc680d798bdbdadb6394f760fac62517/import_ipynb-0.2-py3-none-any.whl.metadata
#   Downloading import_ipynb-0.2-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: IPython in c:\users\ayush ranjan\anaconda3\lib\site-packages (from import-ipynb) (8.15.0)
# Requirement already satisfied: nbformat in c:\users\ayush ranjan\anaconda3\lib\site-packages (from import-ipynb) (5.9.2)
# Requirement already satisfied: backcall in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: colorama in c:\users\ayush ranjan\anaconda3\lib\site-packages (from IPython->import-ipynb) (0.4.6)
# Requirement already satisfied: fastjsonschema in c:\users\ayush ranjan\anaconda3\lib\site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from nbformat->import-ipynb) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\ayush ranjan\anaconda3\lib\site-packages (from nbformat->import-ipynb) (5.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\ayush ranjan\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jupyter-core->nbformat->import-ipynb) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ayush ranjan\anaconda3\lib\site-packages (from jupyter-core->nbformat->import-ipynb) (305.1)
# Requirement already satisfied: executing in c:\users\ayush ranjan\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ayush ranjan\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ayush ranjan\anaconda3\lib\site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: six in c:\users\ayush ranjan\anaconda3\lib\site-packages (from asttokens->stack-data->IPython->import-ipynb) (1.16.0)
# Downloading import_ipynb-0.2-py3-none-any.whl (4.0 kB)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import import_ipynb

# %%
import streamlit as st
import helper
import pickle

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
st.header('Duplicate Question Pairs')
# Out:
# 2025-11-06 22:36:41.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:41.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:41.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
q1 = st.text_input('Enter question 1')
q2 = st.text_input('Enter question 2')
# Out:
# 2025-11-06 22:36:46.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:36:46.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if st.button('Find'):
    query = helper.query_point_creator(q1,q2)
    result = model.predict(query)[0]

    if result:
        st.header('Duplicate')
    else:
        st.header('Not Duplicate')
# Out:
# 2025-11-06 22:37:01.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:37:01.018 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:37:01.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:37:01.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:37:01.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 22:37:01.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# !jupyter nbconvert --to script app.ipynb
# Out:
# [NbConvertApp] Converting notebook app.ipynb to script
# [NbConvertApp] Writing 715 bytes to app.py
